# %%
import pandas as pd

# %%
X_train = pd.read_csv('./data/X_train.csv')
y_train = pd.read_csv('./data/y_train.csv')

# %%
pd.concat([X_train, y_train], axis=1)
# Out:
#      Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0           124            7.8             0.500         0.17             1.6
# 1           563            7.6             0.290         0.49             2.7
# 2           670            6.9             0.400         0.24             2.5
# 3           240            8.9             0.635         0.37             1.7
# 4           481            9.4             0.300         0.56             2.8
# ..          ...            ...               ...          ...             ...
# 954         620            8.3             0.540         0.24             3.4
# 955        1587            5.8             0.610         0.11             1.8
# 956        1211            6.6             0.440         0.15             2.1
# 957        1394            6.4             0.570         0.14             3.9
# 958         760            9.0             0.580         0.25             2.8
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0        0.082                 21.0                 102.0  0.99600  3.39
# 1        0.092                 25.0                  60.0  0.99710  3.31
# 2        0.083                 30.0                  45.0  0.99590  3.26
# 3        0.263                  5.0                  62.0  0.99710  3.00
# 4        0.080                  6.0                  17.0  0.99640  3.15
# ..         ...                  ...                   ...      ...   ...
# 954      0.076                 16.0                 112.0  0.99760  3.27
# 955      0.066                 18.0                  28.0  0.99483  3.55
# 956      0.076                 22.0                  53.0  0.99570  3.32
# 957      0.070                 27.0                  73.0  0.99669  3.32
# 958      0.075                  9.0                 104.0  0.99779  3.23
#
#      sulphates  alcohol  Unnamed: 0  quality
# 0         0.48      9.5         124        5
# 1         0.61     10.1         563        6
# 2         0.58     10.0         670        5
# 3         1.09      9.3         240        5
# 4         0.92     11.7         481        8
# ..         ...      ...         ...      ...
# 954       0.61      9.4         620        5
# 955       0.66     10.9        1587        6
# 956       0.62      9.3        1211        5
# 957       0.48      9.2        1394        5
# 958       0.57      9.7         760        5
#
# [959 rows x 14 columns]
